# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#                                               0.0/2.1 MB ? eta -:--:--
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      --                                       0.1/2.1 MB 3.3 MB/s eta 0:00:01
#      ---                                      0.2/2.1 MB 350.1 kB/s eta 0:00:06
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ploting

# %%
bitcoin_data = pd.read_csv(r"C:\Users\yaswa\OneDrive\Desktop\Jaswanth documents\assignment\ass_1\bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv")

# %%
bitcoin_data.head
# Out:
# <bound method NDFrame.head of           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
bitcoin_data1 = pd.DataFrame(bitcoin_data)

# %%
bitcoin_data1.head(100)
# Out:
#      Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0   1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1   1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2   1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3   1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4   1325318160   NaN   NaN   NaN    NaN           NaN                NaN
# ..         ...   ...   ...   ...    ...           ...                ...
# 95  1325323620   NaN   NaN   NaN    NaN           NaN                NaN
# 96  1325323680   NaN   NaN   NaN    NaN           NaN                NaN
# 97  1325323740   NaN   NaN   NaN    NaN           NaN                NaN
# 98  1325323800   NaN   NaN   NaN    NaN           NaN                NaN
# 99  1325323860   NaN   NaN   NaN    NaN           NaN                NaN
#
#     Weighted_Price
# 0             4.39
# 1              NaN
# 2              NaN
# ...

# %%
bitcoin_data1.info
# Out:
# <bound method DataFrame.info of           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
bitcoin_data1.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  4.857377e+06  3.613769e+06  3.613769e+06  3.613769e+06  3.613769e+06
# mean   1.471301e+09  6.009024e+03  6.013357e+03  6.004488e+03  6.009014e+03
# std    8.428019e+07  8.996247e+03  9.003521e+03  8.988778e+03  8.996360e+03
# min    1.325318e+09  3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00
# 25%    1.398179e+09  4.438600e+02  4.440000e+02  4.435200e+02  4.438600e+02
# 50%    1.471428e+09  3.596970e+03  3.598190e+03  3.595620e+03  3.597000e+03
# 75%    1.544288e+09  8.627270e+03  8.632980e+03  8.621090e+03  8.627160e+03
# max    1.617149e+09  6.176356e+04  6.178183e+04  6.167355e+04  6.178180e+04
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# count  3.613769e+06       3.613769e+06    3.613769e+06
# mean   9.323249e+00       4.176284e+04    6.008935e+03
# std    3.054989e+01       1.518248e+05    8.995992e+03
# min    0.000000e+00       0.000000e+00    3.800000e+00
# ...

# %%
bitcoin_data1.isnull
# Out:
# <bound method DataFrame.isnull of           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
bn = bitcoin_data1.isnull

# %%
new_dn = bitcoin_data1.dropna()

# %%
new_dn.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  3.613769e+06  3.613769e+06  3.613769e+06  3.613769e+06  3.613769e+06
# mean   1.497898e+09  6.009024e+03  6.013357e+03  6.004488e+03  6.009014e+03
# std    7.443689e+07  8.996247e+03  9.003521e+03  8.988778e+03  8.996360e+03
# min    1.325318e+09  3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00
# 25%    1.433683e+09  4.438600e+02  4.440000e+02  4.435200e+02  4.438600e+02
# 50%    1.505880e+09  3.596970e+03  3.598190e+03  3.595620e+03  3.597000e+03
# 75%    1.562208e+09  8.627270e+03  8.632980e+03  8.621090e+03  8.627160e+03
# max    1.617149e+09  6.176356e+04  6.178183e+04  6.167355e+04  6.178180e+04
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# count  3.613769e+06       3.613769e+06    3.613769e+06
# mean   9.323249e+00       4.176284e+04    6.008935e+03
# std    3.054989e+01       1.518248e+05    8.995992e+03
# min    0.000000e+00       0.000000e+00    3.800000e+00
# ...

# %%
new_dn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3613769 entries, 0 to 4857376
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          int64
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: float64(7), int64(1)
# memory usage: 248.1 MB

# %%
new_dn.isnull()
# Out:
#          Timestamp   Open   High    Low  Close  Volume_(BTC)  \
# 0            False  False  False  False  False         False
# 478          False  False  False  False  False         False
# 547          False  False  False  False  False         False
# 548          False  False  False  False  False         False
# 1224         False  False  False  False  False         False
# ...            ...    ...    ...    ...    ...           ...
# 4857372      False  False  False  False  False         False
# 4857373      False  False  False  False  False         False
# 4857374      False  False  False  False  False         False
# 4857375      False  False  False  False  False         False
# 4857376      False  False  False  False  False         False
#
#          Volume_(Currency)  Weighted_Price
# 0                    False           False
# 478                  False           False
# 547                  False           False
# 548                  False           False
# ...

# %%
new_dn.head(10)
# Out:
#        Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0     1325317920  4.39  4.39  4.39   4.39      0.455581           2.000000
# 478   1325346600  4.39  4.39  4.39   4.39     48.000000         210.720000
# 547   1325350740  4.50  4.57  4.50   4.57     37.862297         171.380338
# 548   1325350800  4.58  4.58  4.58   4.58      9.000000          41.220000
# 1224  1325391360  4.58  4.58  4.58   4.58      1.502000           6.879160
# 1896  1325431680  4.84  4.84  4.84   4.84     10.000000          48.400000
# 2333  1325457900  5.00  5.00  5.00   5.00     10.100000          50.500000
# 3612  1325534640  5.00  5.00  5.00   5.00     19.048000          95.240000
# 4553  1325591100  5.32  5.32  5.32   5.32      2.419173          12.870000
# 4710  1325600520  5.14  5.14  5.14   5.14      0.680000           3.495200
#
#       Weighted_Price
# 0           4.390000
# 478         4.390000
# 547         4.526411
# 548         4.580000
# 1224        4.580000
# ...

# %%
new_dn.plot(kind = 'scatter', x="Timestamp", y="Open")
ploting.plot(new_dn["Volume_(BTC)"].head(1))
#ploting.legend(Volume)
ploting.xlabel(Volume_(BTC))
ploting.ylabel(Weighted_Price)
ploting.legend(Volume)
ploting.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\yaswa\OneDrive\Desktop\Jaswanth documents\assignment\ass_1\Bitcoin_Data.ipynb Cell 17 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/yaswa/OneDrive/Desktop/Jaswanth%20documents/assignment/ass_1/Bitcoin_Data.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> ploting.plot(new_dn["Volume_(BTC)"].head(1))
#       <a href='vscode-notebook-cell:/c%3A/Users/yaswa/OneDrive/Desktop/Jaswanth%20documents/assignment/ass_1/Bitcoin_Data.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> #ploting.legend(Volume)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yaswa/OneDrive/Desktop/Jaswanth%20documents/assignment/ass_1/Bitcoin_Data.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> ploting.xlabel(Volume_(BTC))
# ...

# %%
ploting.show()

# %%
ploting.plot(new_dn['Open'].head(100))
ploting.legend(['Open ']) 
# x_label set here.
ploting.xlabel('Time period')
# y_label set here.
ploting.ylabel('Opening price')
# title set here.
ploting.title('Total number of Opening price of Bitcoin for Starting 1000 timestamps')
ploting.show()

# %%
ploting.subplot(2,2,1)
ploting.plot(new_dn['Open']) 
ploting.legend(['Open '])
ploting.xlabel('Time period')
ploting.ylabel('Opening price')

ploting.subplot(2,2,2)
ploting.scatter(new_dn['Weighted_Price'].head(100) ,new_dn['Volume_(BTC)'].head(100),color='red')
ploting.xlabel('Weighted_Price')
ploting.ylabel('Volume_(BTC)')
ploting.show()

# %%
# define figure size.
ploting.figure(figsize = (20,10)) 
ploting.rcParams.update({'font.size': 10}) 
ploting.subplot(2,1,1)
ploting.plot(New_Dataset1['Open'].head(1000))
ploting.legend(['Open price']) 
# x_label set here.
ploting.xlabel('Time period')
# y_label set here.
ploting.ylabel('Open')
# title set here.
ploting.title('Total number of Opening price of Bitcoin for Starting 1000 timestamps')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\yaswa\OneDrive\Desktop\Jaswanth documents\assignment\ass_1\Bitcoin_Data.ipynb Cell 21 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/yaswa/OneDrive/Desktop/Jaswanth%20documents/assignment/ass_1/Bitcoin_Data.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> ploting.rcParams.update({'font.size': 10})
#       <a href='vscode-notebook-cell:/c%3A/Users/yaswa/OneDrive/Desktop/Jaswanth%20documents/assignment/ass_1/Bitcoin_Data.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> ploting.subplot(2,1,1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yaswa/OneDrive/Desktop/Jaswanth%20documents/assignment/ass_1/Bitcoin_Data.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> ploting.plot(New_Dataset1['Open'].head(1000))
# ...
